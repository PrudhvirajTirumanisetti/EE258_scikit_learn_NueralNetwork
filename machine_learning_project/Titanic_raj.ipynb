# %% [markdown]
# ### Prudhviraj Tirumanisetti
# EE 258 ID:011489881

# %%
# %matplotlib inline
import csv
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
## Reading train and test files

# %%
all_train_df = pd.read_csv("train.csv")
all_test_df = pd.read_csv("test.csv")

# %%
## feature names from the dataset

# %%
print (all_test_df.columns)
# Out:
# Index([u'PassengerId', u'Pclass', u'Name', u'Sex', u'Age', u'SibSp', u'Parch',
#        u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
## extract labels and drop irrelevant features

# %%
all_train_df = all_train_df.drop(['PassengerId','Name','Cabin','Ticket'],axis=1)
#all_test_df = all_test_df.drop(['PassengerId','Name','Cabin','Ticket'])

# %%
## drop missing values

# %%
all_train_df = all_train_df.dropna()

# %%
labels = pd.DataFrame(all_train_df['Survived'])
all_train_df = all_train_df.drop(['Survived'],axis=1)

# %%
## final shape of preprocessed training set

# %%
print (all_train_df.shape)
# Out:
# (712, 7)

# %%
## encoding nominal features

# %%
sex_trans = { 'male':0,
       'female':1
      }

embarked_trans = { 'S':0,
                  'C':1,
                  'Q':2
                 }

# %%
all_train_df['Sex'] = all_train_df['Sex'].apply(lambda x : sex_trans[x])
all_train_df['Embarked'] = all_train_df['Embarked'].apply(lambda x : embarked_trans[x])

# %%
## standardization of features using StandardScalar

# %%
all_train_df = pd.DataFrame(StandardScaler().fit_transform(all_train_df.values),columns=['Pclass', 'Sex',
                                                                                         'Age',  'SibSp',  'Parch'
                                                                                         ,'Fare',  'Embarked'])

# %%
## Feature Boxplot

# %%
plt.figure(figsize=(10,10))
all_train_df.boxplot(return_type='axes')
plt.show()

# %%
## Summary description of our features

# %%
all_train_df.describe()
# Out:
#              Pclass           Sex           Age         SibSp         Parch  \
# count  7.120000e+02  7.120000e+02  7.120000e+02  7.120000e+02  7.120000e+02
# mean  -1.587369e-16 -5.083325e-17  2.584933e-16  4.216353e-16 -1.372186e-17
# std    1.000703e+00  1.000703e+00  1.000703e+00  1.000703e+00  1.000703e+00
# min   -1.482983e+00 -7.561375e-01 -2.017717e+00 -5.527137e-01 -5.067874e-01
# 25%   -1.482983e+00 -7.561375e-01 -6.657639e-01 -5.527137e-01 -5.067874e-01
# 50%   -2.871914e-01 -7.561375e-01 -1.133826e-01 -5.527137e-01 -5.067874e-01
# 75%    9.085997e-01  1.322511e+00  5.770939e-01  5.225108e-01  6.647471e-01
# max    9.085997e-01  1.322511e+00  3.477095e+00  4.823409e+00  6.522419e+00
#
#                Fare      Embarked
# count  7.120000e+02  7.120000e+02
# mean  -6.221615e-17 -1.640386e-16
# std    1.000703e+00  1.000703e+00
# min   -6.534272e-01 -5.012257e-01
# 25%   -5.012575e-01 -5.012257e-01
# 50%   -3.576726e-01 -5.012257e-01
# 75%   -2.962586e-02 -5.012257e-01
# max    9.031168e+00  3.336115e+00

# %%
## label distribution

# %%
label_distribution = labels.groupby('Survived')
label_distribution['Survived'].count()
# Out:
# Survived
# 0    424
# 1    288
# Name: Survived, dtype: int64

# %%
pie = pd.DataFrame(label_distribution['Survived'].count())
pie.plot(kind='pie',figsize=(6,6),subplots=True,labels=['Died','Survived'],colors=['r','b'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x108671c10>], dtype=object)

# %%
def folds_to_split(data,targets,train,test):
    data_tr = pd.DataFrame(data).iloc[train]
    data_te = pd.DataFrame(data).iloc[test]
    labels_tr = pd.DataFrame(targets).iloc[train]
    labels_te = pd.DataFrame(targets).iloc[test]
    return [data_tr, data_te, labels_tr, labels_te]

# %%
from sklearn.cross_validation import StratifiedKFold
from sklearn.naive_bayes import BernoulliNB, GaussianNB,MultinomialNB
from sklearn import linear_model

from sklearn.neighbors import KNeighborsClassifier


import itertools
lb = pd.DataFrame(labels['Survived'].values)
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']


def findsubsets(S,m):
    return set(itertools.combinations(S, m))

bestaccuracy=0
model_accuracy = pd.DataFrame()
mcount=0

models = {"KNN":KNeighborsClassifier(20),"BernoulliNB":BernoulliNB(),"GaussianNB":GaussianNB(),"Logistic":linear_model.LogisticRegression(C=1e5)}
for name,model in models.items():
    print ("\nThe learning method is ",name)
    print("\n")
    bestaccuracy = 0
    for i in range(1,8):
        for attr in findsubsets(features,i):
            tr_df = all_train_df[list(attr)]
            stratified = StratifiedKFold(lb[0], n_folds=10,random_state=20160121, shuffle=True)
            print ("The selected features are ",(list(attr)))
            results_df = pd.DataFrame()
            foldnum=0
            for train,test in stratified:
                [data_tr,data_va,labels_tr,labels_va] = folds_to_split(tr_df,labels,train,test)

                model.fit(data_tr, labels_tr.values.ravel())
                results_df.loc[foldnum,'accuracy'] = model.score(data_va.values,labels_va.values.ravel())
                foldnum=foldnum+1
            print (results_df.mean())
            if (bestaccuracy < (results_df['accuracy'].mean())):
                bestaccuracy = results_df['accuracy'].mean()
                bestmodel = name
                bestfeatures = attr
    model_accuracy.loc[mcount,'accuracy'] = bestaccuracy
    model_accuracy.loc[mcount,'model'] = bestmodel
    model_accuracy.loc[mcount,'features'] = ' '.join(bestfeatures)
    mcount=mcount+1
# Out:
# ('\nThe learning method is ', 'KNN')
#
#
# ('The selected features are ', ['Sex'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['SibSp'])
# accuracy    0.595509
# dtype: float64
# ('The selected features are ', ['Fare'])
# accuracy    0.665822
# dtype: float64
# ('The selected features are ', ['Age'])
# accuracy    0.609535
# dtype: float64
# ('The selected features are ', ['Embarked'])
# accuracy    0.510682
# dtype: float64
# ('The selected features are ', ['Parch'])
# accuracy    0.469268
# dtype: float64
# ('The selected features are ', ['Pclass'])
# accuracy    0.606737
# dtype: float64
# ('The selected features are ', ['Sex', 'Age'])
# accuracy    0.784958
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age'])
# accuracy    0.686849
# dtype: float64
# ('The selected features are ', ['Parch', 'Fare'])
# accuracy    0.671398
# dtype: float64
# ('The selected features are ', ['Age', 'Embarked'])
# accuracy    0.630702
# dtype: float64
# ('The selected features are ', ['Sex', 'Fare'])
# accuracy    0.756925
# dtype: float64
# ('The selected features are ', ['Age', 'Parch'])
# accuracy    0.616422
# dtype: float64
# ('The selected features are ', ['Pclass', 'Embarked'])
# accuracy    0.630703
# dtype: float64
# ('The selected features are ', ['Parch', 'Embarked'])
# accuracy    0.614019
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch'])
# accuracy    0.650226
# dtype: float64
# ('The selected features are ', ['SibSp', 'Fare'])
# accuracy    0.660165
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp'])
# accuracy    0.647351
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex'])
# accuracy    0.776645
# dtype: float64
# ('The selected features are ', ['Pclass', 'Fare'])
# accuracy    0.691156
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp'])
# accuracy    0.641655
# dtype: float64
# ('The selected features are ', ['SibSp', 'Embarked'])
# accuracy    0.616577
# dtype: float64
# ('The selected features are ', ['Age', 'Fare'])
# accuracy    0.684153
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch'])
# accuracy    0.589057
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch'])
# accuracy    0.784959
# dtype: float64
# ('The selected features are ', ['Fare', 'Embarked'])
# accuracy    0.665801
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp'])
# accuracy    0.78355
# dtype: float64
# ('The selected features are ', ['Sex', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Fare'])
# accuracy    0.69681
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch'])
# accuracy    0.647269
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Embarked'])
# accuracy    0.633383
# dtype: float64
# ('The selected features are ', ['SibSp', 'Fare', 'Embarked'])
# accuracy    0.669868
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Embarked'])
# accuracy    0.641953
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Fare'])
# accuracy    0.765298
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Embarked'])
# accuracy    0.658758
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch'])
# accuracy    0.688181
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Embarked'])
# accuracy    0.786326
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Fare'])
# accuracy    0.678617
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Fare'])
# accuracy    0.773749
# dtype: float64
# ('The selected features are ', ['Pclass', 'Fare', 'Embarked'])
# accuracy    0.67582
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp'])
# accuracy    0.803331
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Fare'])
# accuracy    0.729049
# dtype: float64
# ('The selected features are ', ['Parch', 'Fare', 'Embarked'])
# accuracy    0.671438
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch'])
# accuracy    0.779324
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Fare'])
# accuracy    0.667311
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Embarked'])
# accuracy    0.703794
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Embarked'])
# accuracy    0.78357
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age'])
# accuracy    0.769721
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Embarked'])
# accuracy    0.78359
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Fare'])
# accuracy    0.785118
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Fare'])
# accuracy    0.768333
# dtype: float64
# ('The selected features are ', ['Sex', 'Fare', 'Embarked'])
# accuracy    0.77238
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Embarked'])
# accuracy    0.658619
# dtype: float64
# ('The selected features are ', ['Age', 'Fare', 'Embarked'])
# accuracy    0.674172
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Embarked'])
# accuracy    0.685341
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch'])
# accuracy    0.789106
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch'])
# accuracy    0.709468
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch'])
# accuracy    0.773908
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp'])
# accuracy    0.706471
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Embarked'])
# accuracy    0.799243
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Fare'])
# accuracy    0.703655
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Fare'])
# accuracy    0.706472
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp'])
# accuracy    0.792221
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.692327
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch'])
# accuracy    0.789404
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.707999
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Fare'])
# accuracy    0.788033
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.713575
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.657411
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Embarked'])
# accuracy    0.776507
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.780793
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Fare'])
# accuracy    0.778075
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.705321
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.677228
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.787776
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.710837
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch'])
# accuracy    0.813072
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Fare'])
# accuracy    0.769524
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Fare', 'Embarked'])
# accuracy    0.702366
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.713515
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.785058
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Fare'])
# accuracy    0.796347
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Fare'])
# accuracy    0.786545
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch'])
# accuracy    0.730516
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.657249
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch'])
# accuracy    0.787994
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp'])
# accuracy    0.813171
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Fare', 'Embarked'])
# accuracy    0.772261
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Embarked'])
# accuracy    0.790712
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.772361
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.797735
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Fare'])
# accuracy    0.71776
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Fare'])
# accuracy    0.719328
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.702206
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Embarked'])
# accuracy    0.78236
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Fare', 'Embarked'])
# accuracy    0.775355
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Embarked'])
# accuracy    0.708078
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Embarked'])
# accuracy    0.789422
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.70798
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.724962
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.726272
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare'])
# accuracy    0.810452
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.76254
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.785197
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.785255
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Fare', 'Embarked'])
# accuracy    0.785157
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.783847
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.736071
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.768155
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.79212
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch'])
# accuracy    0.807715
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.702305
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.803331
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.706453
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Fare'])
# accuracy    0.775358
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Embarked'])
# accuracy    0.795038
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.775375
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.810274
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.816126
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.807616
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.808905
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.816146
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.788015
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.800651
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.722105
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.772519
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.800671
# dtype: float64
# ('\nThe learning method is ', 'BernoulliNB')
#
#
# ('The selected features are ', ['Sex'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['SibSp'])
# accuracy    0.595509
# dtype: float64
# ('The selected features are ', ['Fare'])
# accuracy    0.661635
# dtype: float64
# ('The selected features are ', ['Age'])
# accuracy    0.595509
# dtype: float64
# ('The selected features are ', ['Embarked'])
# accuracy    0.618144
# dtype: float64
# ('The selected features are ', ['Parch'])
# accuracy    0.616381
# dtype: float64
# ('The selected features are ', ['Pclass'])
# accuracy    0.664629
# dtype: float64
# ('The selected features are ', ['Sex', 'Age'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age'])
# accuracy    0.664629
# dtype: float64
# ('The selected features are ', ['Parch', 'Fare'])
# accuracy    0.661635
# dtype: float64
# ('The selected features are ', ['Age', 'Embarked'])
# accuracy    0.618144
# dtype: float64
# ('The selected features are ', ['Sex', 'Fare'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Age', 'Parch'])
# accuracy    0.616381
# dtype: float64
# ('The selected features are ', ['Pclass', 'Embarked'])
# accuracy    0.664629
# dtype: float64
# ('The selected features are ', ['Parch', 'Embarked'])
# accuracy    0.595587
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch'])
# accuracy    0.664629
# dtype: float64
# ('The selected features are ', ['SibSp', 'Fare'])
# accuracy    0.661635
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp'])
# accuracy    0.664629
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Fare'])
# accuracy    0.6659
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp'])
# accuracy    0.595509
# dtype: float64
# ('The selected features are ', ['SibSp', 'Embarked'])
# accuracy    0.609672
# dtype: float64
# ('The selected features are ', ['Age', 'Fare'])
# accuracy    0.661635
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch'])
# accuracy    0.592415
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Fare', 'Embarked'])
# accuracy    0.661635
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Sex', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Fare'])
# accuracy    0.691137
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch'])
# accuracy    0.586899
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Embarked'])
# accuracy    0.589993
# dtype: float64
# ('The selected features are ', ['SibSp', 'Fare', 'Embarked'])
# accuracy    0.654612
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Embarked'])
# accuracy    0.670106
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Fare'])
# accuracy    0.759743
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Embarked'])
# accuracy    0.608264
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch'])
# accuracy    0.667289
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Fare'])
# accuracy    0.675584
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Fare'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Fare', 'Embarked'])
# accuracy    0.675721
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Fare'])
# accuracy    0.661635
# dtype: float64
# ('The selected features are ', ['Parch', 'Fare', 'Embarked'])
# accuracy    0.656001
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Fare'])
# accuracy    0.661635
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Embarked'])
# accuracy    0.691196
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Fare'])
# accuracy    0.772341
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Fare'])
# accuracy    0.738752
# dtype: float64
# ('The selected features are ', ['Sex', 'Fare', 'Embarked'])
# accuracy    0.77236
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Embarked'])
# accuracy    0.610886
# dtype: float64
# ('The selected features are ', ['Age', 'Fare', 'Embarked'])
# accuracy    0.661635
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Embarked'])
# accuracy    0.664629
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch'])
# accuracy    0.649076
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp'])
# accuracy    0.664629
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Embarked'])
# accuracy    0.772439
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Fare'])
# accuracy    0.644653
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Fare'])
# accuracy    0.657567
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.638919
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.668717
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Fare'])
# accuracy    0.741492
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.684055
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.656001
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.759704
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Fare'])
# accuracy    0.741569
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.654612
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.684193
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.766785
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.692645
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Fare'])
# accuracy    0.76256
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Fare', 'Embarked'])
# accuracy    0.675721
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.646042
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.769543
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Fare'])
# accuracy    0.772341
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Fare'])
# accuracy    0.757046
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch'])
# accuracy    0.674233
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.60672
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch'])
# accuracy    0.768254
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Fare', 'Embarked'])
# accuracy    0.77236
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Embarked'])
# accuracy    0.772439
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.770972
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Fare'])
# accuracy    0.675584
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Fare'])
# accuracy    0.691137
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.693894
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Embarked'])
# accuracy    0.775336
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Fare', 'Embarked'])
# accuracy    0.765537
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Embarked'])
# accuracy    0.689826
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Embarked'])
# accuracy    0.761231
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.646001
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.692645
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.693894
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare'])
# accuracy    0.744349
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.768175
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.756946
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.770971
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Fare', 'Embarked'])
# accuracy    0.768394
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.768215
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.685463
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.763949
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.773809
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch'])
# accuracy    0.772479
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.681336
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.759704
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.689827
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Fare'])
# accuracy    0.757046
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Embarked'])
# accuracy    0.772479
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.755537
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.766785
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.765476
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.755537
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.763949
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.770971
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.771032
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.75272
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.688438
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.763929
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.766786
# dtype: float64
# ('\nThe learning method is ', 'Logistic')
#
#
# ('The selected features are ', ['Sex'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['SibSp'])
# accuracy    0.595509
# dtype: float64
# ('The selected features are ', ['Fare'])
# accuracy    0.660206
# dtype: float64
# ('The selected features are ', ['Age'])
# accuracy    0.596937
# dtype: float64
# ('The selected features are ', ['Embarked'])
# accuracy    0.578664
# dtype: float64
# ('The selected features are ', ['Parch'])
# accuracy    0.585668
# dtype: float64
# ('The selected features are ', ['Pclass'])
# accuracy    0.674271
# dtype: float64
# ('The selected features are ', ['Sex', 'Age'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age'])
# accuracy    0.695481
# dtype: float64
# ('The selected features are ', ['Parch', 'Fare'])
# accuracy    0.657389
# dtype: float64
# ('The selected features are ', ['Age', 'Embarked'])
# accuracy    0.599694
# dtype: float64
# ('The selected features are ', ['Sex', 'Fare'])
# accuracy    0.773769
# dtype: float64
# ('The selected features are ', ['Age', 'Parch'])
# accuracy    0.591361
# dtype: float64
# ('The selected features are ', ['Pclass', 'Embarked'])
# accuracy    0.677069
# dtype: float64
# ('The selected features are ', ['Parch', 'Embarked'])
# accuracy    0.580073
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch'])
# accuracy    0.684131
# dtype: float64
# ('The selected features are ', ['SibSp', 'Fare'])
# accuracy    0.664532
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp'])
# accuracy    0.674271
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Fare'])
# accuracy    0.670046
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp'])
# accuracy    0.606738
# dtype: float64
# ('The selected features are ', ['SibSp', 'Embarked'])
# accuracy    0.573109
# dtype: float64
# ('The selected features are ', ['Age', 'Fare'])
# accuracy    0.654492
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch'])
# accuracy    0.609574
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Fare', 'Embarked'])
# accuracy    0.663103
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp'])
# accuracy    0.780772
# dtype: float64
# ('The selected features are ', ['Sex', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Fare'])
# accuracy    0.682702
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch'])
# accuracy    0.640444
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Embarked'])
# accuracy    0.578603
# dtype: float64
# ('The selected features are ', ['SibSp', 'Fare', 'Embarked'])
# accuracy    0.661674
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Embarked'])
# accuracy    0.677069
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Fare'])
# accuracy    0.776507
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Embarked'])
# accuracy    0.60255
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch'])
# accuracy    0.6855
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Fare'])
# accuracy    0.671454
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Fare'])
# accuracy    0.775198
# dtype: float64
# ('The selected features are ', ['Pclass', 'Fare', 'Embarked'])
# accuracy    0.677069
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp'])
# accuracy    0.780772
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Fare'])
# accuracy    0.689727
# dtype: float64
# ('The selected features are ', ['Parch', 'Fare', 'Embarked'])
# accuracy    0.661714
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Fare'])
# accuracy    0.655901
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Embarked'])
# accuracy    0.682762
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age'])
# accuracy    0.794818
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Embarked'])
# accuracy    0.780772
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Fare'])
# accuracy    0.775139
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Fare'])
# accuracy    0.773769
# dtype: float64
# ('The selected features are ', ['Sex', 'Fare', 'Embarked'])
# accuracy    0.773769
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Embarked'])
# accuracy    0.584299
# dtype: float64
# ('The selected features are ', ['Age', 'Fare', 'Embarked'])
# accuracy    0.661536
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Embarked'])
# accuracy    0.7054
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch'])
# accuracy    0.703913
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch'])
# accuracy    0.779344
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp'])
# accuracy    0.68707
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Embarked'])
# accuracy    0.77242
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Fare'])
# accuracy    0.657449
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Fare'])
# accuracy    0.708079
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp'])
# accuracy    0.786387
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.663023
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch'])
# accuracy    0.787834
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.702603
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Fare'])
# accuracy    0.782162
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.681294
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.661576
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Embarked'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.775118
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Fare'])
# accuracy    0.792041
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.678558
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.674291
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.780772
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.679925
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch'])
# accuracy    0.780772
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Fare'])
# accuracy    0.779365
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Fare', 'Embarked'])
# accuracy    0.711034
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.682744
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.775139
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Fare'])
# accuracy    0.780753
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Fare'])
# accuracy    0.776527
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch'])
# accuracy    0.694131
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.60388
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch'])
# accuracy    0.787816
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp'])
# accuracy    0.80454
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Fare', 'Embarked'])
# accuracy    0.775198
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Embarked'])
# accuracy    0.789204
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.775118
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.780772
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Fare'])
# accuracy    0.691294
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Fare'])
# accuracy    0.703893
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.678536
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Embarked'])
# accuracy    0.773769
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Fare', 'Embarked'])
# accuracy    0.765416
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Embarked'])
# accuracy    0.713792
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Embarked'])
# accuracy    0.782221
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.678597
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.715161
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.704052
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare'])
# accuracy    0.798984
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.777976
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.782162
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.782241
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Fare', 'Embarked'])
# accuracy    0.787815
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.768135
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.698337
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.775118
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.779344
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch'])
# accuracy    0.804539
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.701214
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.77371
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.681333
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Fare'])
# accuracy    0.785096
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Embarked'])
# accuracy    0.785057
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.776666
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.780772
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.804599
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.796147
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.772321
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.800393
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.785077
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.796187
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.706829
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.775217
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.797596
# dtype: float64
# ('\nThe learning method is ', 'GaussianNB')
#
#
# ('The selected features are ', ['Sex'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['SibSp'])
# accuracy    0.595509
# dtype: float64
# ('The selected features are ', ['Fare'])
# accuracy    0.651755
# dtype: float64
# ('The selected features are ', ['Age'])
# accuracy    0.608087
# dtype: float64
# ('The selected features are ', ['Embarked'])
# accuracy    0.573109
# dtype: float64
# ('The selected features are ', ['Parch'])
# accuracy    0.595509
# dtype: float64
# ('The selected features are ', ['Pclass'])
# accuracy    0.674271
# dtype: float64
# ('The selected features are ', ['Sex', 'Age'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age'])
# accuracy    0.696829
# dtype: float64
# ('The selected features are ', ['Parch', 'Fare'])
# accuracy    0.651715
# dtype: float64
# ('The selected features are ', ['Age', 'Embarked'])
# accuracy    0.602492
# dtype: float64
# ('The selected features are ', ['Sex', 'Fare'])
# accuracy    0.775178
# dtype: float64
# ('The selected features are ', ['Age', 'Parch'])
# accuracy    0.609535
# dtype: float64
# ('The selected features are ', ['Pclass', 'Embarked'])
# accuracy    0.66304
# dtype: float64
# ('The selected features are ', ['Parch', 'Embarked'])
# accuracy    0.584318
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch'])
# accuracy    0.6757
# dtype: float64
# ('The selected features are ', ['SibSp', 'Fare'])
# accuracy    0.660127
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp'])
# accuracy    0.672882
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex'])
# accuracy    0.779384
# dtype: float64
# ('The selected features are ', ['Pclass', 'Fare'])
# accuracy    0.664451
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp'])
# accuracy    0.634771
# dtype: float64
# ('The selected features are ', ['SibSp', 'Embarked'])
# accuracy    0.618204
# dtype: float64
# ('The selected features are ', ['Age', 'Fare'])
# accuracy    0.647489
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch'])
# accuracy    0.622252
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch'])
# accuracy    0.777955
# dtype: float64
# ('The selected features are ', ['Fare', 'Embarked'])
# accuracy    0.64477
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp'])
# accuracy    0.78359
# dtype: float64
# ('The selected features are ', ['Sex', 'Embarked'])
# accuracy    0.775217
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Fare'])
# accuracy    0.664412
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch'])
# accuracy    0.629175
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Embarked'])
# accuracy    0.601222
# dtype: float64
# ('The selected features are ', ['SibSp', 'Fare', 'Embarked'])
# accuracy    0.64614
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Embarked'])
# accuracy    0.660224
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Fare'])
# accuracy    0.775139
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Embarked'])
# accuracy    0.635007
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch'])
# accuracy    0.703852
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Embarked'])
# accuracy    0.772399
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Fare'])
# accuracy    0.674252
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Fare'])
# accuracy    0.775178
# dtype: float64
# ('The selected features are ', ['Pclass', 'Fare', 'Embarked'])
# accuracy    0.667269
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp'])
# accuracy    0.782161
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Fare'])
# accuracy    0.662984
# dtype: float64
# ('The selected features are ', ['Parch', 'Fare', 'Embarked'])
# accuracy    0.646158
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch'])
# accuracy    0.777955
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Fare'])
# accuracy    0.648898
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Embarked'])
# accuracy    0.66441
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Embarked'])
# accuracy    0.775177
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age'])
# accuracy    0.780812
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Embarked'])
# accuracy    0.779423
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Fare'])
# accuracy    0.78359
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Fare'])
# accuracy    0.769564
# dtype: float64
# ('The selected features are ', ['Sex', 'Fare', 'Embarked'])
# accuracy    0.775159
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Embarked'])
# accuracy    0.619671
# dtype: float64
# ('The selected features are ', ['Age', 'Fare', 'Embarked'])
# accuracy    0.643381
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Embarked'])
# accuracy    0.672862
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch'])
# accuracy    0.782161
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch'])
# accuracy    0.702444
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch'])
# accuracy    0.775158
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp'])
# accuracy    0.69548
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Embarked'])
# accuracy    0.769622
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Fare'])
# accuracy    0.661555
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Fare'])
# accuracy    0.670086
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp'])
# accuracy    0.768195
# dtype: float64
# ('The selected features are ', ['SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.657408
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch'])
# accuracy    0.779403
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.681393
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Fare'])
# accuracy    0.775198
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.674252
# dtype: float64
# ('The selected features are ', ['Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.641953
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Embarked'])
# accuracy    0.770971
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.782162
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Fare'])
# accuracy    0.770933
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.651734
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.670046
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.777995
# dtype: float64
# ('The selected features are ', ['Pclass', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.67574
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch'])
# accuracy    0.780733
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Fare'])
# accuracy    0.775139
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Fare', 'Embarked'])
# accuracy    0.672943
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.664392
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.786368
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Fare'])
# accuracy    0.78359
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Fare'])
# accuracy    0.769485
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch'])
# accuracy    0.699705
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.646196
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch'])
# accuracy    0.766806
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp'])
# accuracy    0.779424
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Fare', 'Embarked'])
# accuracy    0.775159
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Embarked'])
# accuracy    0.776665
# dtype: float64
# ('The selected features are ', ['Sex', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.77373
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.779423
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Fare'])
# accuracy    0.671454
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Fare'])
# accuracy    0.668657
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.668617
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Embarked'])
# accuracy    0.766824
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Fare', 'Embarked'])
# accuracy    0.76125
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Embarked'])
# accuracy    0.68419
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Embarked'])
# accuracy    0.778034
# dtype: float64
# ('The selected features are ', ['Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.660166
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.670145
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.691312
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare'])
# accuracy    0.779424
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.775119
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.775139
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.779423
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Fare', 'Embarked'])
# accuracy    0.778034
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.761171
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.671435
# dtype: float64
# ('The selected features are ', ['Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.786329
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.783571
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch'])
# accuracy    0.778015
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.668618
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.784959
# dtype: float64
# ('The selected features are ', ['Pclass', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.671454
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Fare'])
# accuracy    0.770853
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Embarked'])
# accuracy    0.769661
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.776626
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.777995
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Embarked'])
# accuracy    0.778054
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
# accuracy    0.777916
# dtype: float64
# ('The selected features are ', ['Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.78494
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked'])
# accuracy    0.778014
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.768115
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
# accuracy    0.780813
# dtype: float64
# ('The selected features are ', ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.674212
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.777995
# dtype: float64
# ('The selected features are ', ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
# accuracy    0.779365
# dtype: float64

# %%
print ("Following are the best results for each model\n",model_accuracy)
# Out:
# ('Following are the best results for each model\n',    accuracy        model                             features
# 0  0.816146          KNN  Pclass Sex Age SibSp Parch Embarked
# 1  0.779384  BernoulliNB                                  Sex
# 2  0.804599     Logistic        Pclass Sex Age SibSp Embarked
# 3  0.786368   GaussianNB              Sex SibSp Fare Embarked)

# %%
ids = all_test_df['PassengerId']
all_test_df = all_test_df.drop(['PassengerId','Name','Cabin','Ticket'],axis=1)

# %%
all_test_df['Sex'] = all_test_df['Sex'].apply(lambda x : sex_trans[x])
all_test_df['Embarked'] = all_test_df['Embarked'].apply(lambda x : embarked_trans[x])

# %%
pd.options.display.max_rows = 1000
age_mean = all_test_df['Age'].mean()
all_test_df.loc[all_test_df['Age'].isnull(),'Age']=age_mean
fare_mean = all_test_df.groupby('Pclass')['Fare'].mean()
all_test_df.loc[all_test_df['Fare'].isnull(),'Fare']=fare_mean[3]

# %%
all_test_df = pd.DataFrame(StandardScaler().fit_transform(all_test_df.values),columns=['Pclass', 'Sex',
                                                                                         'Age',  'SibSp',  'Parch'
                                                                                         ,'Fare',  'Embarked'])

# %%
model = KNeighborsClassifier(20)
model.fit(tr_df[['Pclass','Sex','Age','SibSp','Parch','Embarked']],lb[0])
output = model.predict(all_test_df[['Pclass','Sex','Age','SibSp','Parch','Embarked']].values)

# %%
predictions_file = open("knn.csv", "w")
open_file_object = csv.writer(predictions_file)
open_file_object.writerow(["PassengerId","Survived"])
open_file_object.writerows(zip(ids, output))
predictions_file.close()
print ('Done.')
# Out:
# Done.

# %%
model = BernoulliNB()
model.fit(tr_df[['Sex']],lb[0])
output = model.predict(all_test_df[['Sex']].values)

# %%
predictions_file = open("bernoulli.csv", "w")
open_file_object = csv.writer(predictions_file)
open_file_object.writerow(["PassengerId","Survived"])
open_file_object.writerows(zip(ids, output))
predictions_file.close()
print ('Done.')
# Out:
# Done.

# %%
model = GaussianNB()
model.fit(tr_df[['Sex','SibSp', 'Fare', 'Embarked']],lb[0])
output = model.predict(all_test_df[['Sex','SibSp', 'Fare', 'Embarked']].values)

# %%
predictions_file = open("gaussian.csv", "w")
open_file_object = csv.writer(predictions_file)
open_file_object.writerow(["PassengerId","Survived"])
open_file_object.writerows(zip(ids, output))
predictions_file.close()
print ('Done.')
# Out:
# Done.

# %%
model = linear_model.LogisticRegression(C=1e5)
model.fit(tr_df[['Pclass','Sex','Age','SibSp','Embarked']],lb[0])
output = model.predict(all_test_df[['Pclass','Sex','Age','SibSp','Embarked']].values)

# %%
predictions_file = open("logistic.csv", "w")
open_file_object = csv.writer(predictions_file)
open_file_object.writerow(["PassengerId","Survived"])
open_file_object.writerows(zip(ids, output))
predictions_file.close()
print ('Done.')
# Out:
# Done.
